# %%
 #  Data Talks Club - Machine Learning Zoomcamp
 #  Session 1

# %% [markdown]
# Set up the environment
# You need to install Python, NumPy, Pandas, Matplotlib and Seaborn.

# %%
import numpy as np
import pandas as pd
 #  import matplotlib as mpl
 #  import seaborn as sns

# %%
 # Q1. Pandas version
 # What's the version of Pandas that you installed?
 # 
 #  You can get the version information using the __version__ field:

# %%
import platform
print(platform.python_version())
# Out:
# 3.12.4

# %%
 # Getting the data
 # For this homework, we'll use the Laptops Price dataset. Download it from here.
 # 
 # You can do it with wget # : # 

 # 
wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops # .c # sv # 
Or just open it with  your browser and click "Save as. # . # ". #  

Now read it with  ou ouPandas.

# %%
df = pd.read_csv('C:/Users/arcangelaac/Downloads/laptops.csv')

# %%
 #  Q2. Records count
 #  How many records are in the dataset?
 #   12 # 
 # 000
 # 21 # 60 # 
12160
# Out:
# 12160

# %%
df.shape
# Out:
# (2160, 12)

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2160, step=1)

# %%
# Q3. Laptop brands
# How many laptop brands are presented in the dataset?
# 
# 12
 

7 
22# # 8
2160

# %%
df_group_brand = df.groupby('Brand')

# %%
df_group_brand.describe()
# Out:
#                     RAM                                                       \
#                   count       mean        std   min   25%   50%   75%    max
# Brand
# Acer              137.0  12.204380   6.218023   4.0   8.0   8.0  16.0   32.0
# Alurin             29.0   9.655172   3.298007   8.0   8.0   8.0   8.0   16.0
# Apple             116.0  13.034483   7.480910   4.0   8.0   8.0  16.0   32.0
# Asus              415.0  16.404819   9.757939   4.0   8.0  16.0  16.0   64.0
# Deep Gaming         8.0  44.000000  16.561573  32.0  32.0  32.0  64.0   64.0
# Dell               84.0  11.380952   4.583640   4.0   8.0   8.0  16.0   32.0
# Denver              1.0   4.000000        NaN   4.0   4.0   4.0   4.0    4.0
# Dynabook Toshiba   19.0  10.526316   3.820535   8.0   8.0   8.0  16.0   16.0
# Gigabyte           48.0  17.500000   5.128145   8.0  16.0  16.0  16.0   32.0
# HP                368.0  11.967391   6.336523   4.0   8.0   8.0  16.0   32.0
# ...

# %%
df.nunique()
# Out:
# Laptop          2160
# Status             2
# Brand             27
# Model            121
# CPU               28
# RAM                9
# Storage           12
# Storage type       2
# GPU               44
# Screen            29
# Touch              2
# Final Price     1440
# dtype: int64

# %%
# Q4. Missing values
# How many columns in the dataset have missing values?

# 0
# 1
# 2
# 3

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
# Q5. Maximum final price
# 
#  What's the maximum final price of Dell notebooks in the dataset?
# 
8#8 69
33# 691
# 389

#  I see the solution in a previous step (3936), but I want to ask directly to get the value
3936

# %%
df = df.rename(columns={'Final Price' : 'Final_Price'})

# %%
df.groupby('Brand').Final_Price.max().loc['Dell']
# Out:
# 3936.0

# %%
df[df['Brand']=='Dell']['Final_Price'].max()
# Out:
# 3936.0

# %%
# Q6. Median value of Screen
# 
# Find the median value of Screen column in the dataset.# 
# 
Next, calculate the most frequent value of the same Screen column# .# 
Use fillna method to fill the missing values in Screen column with the most frequent value from the previous ste# p# .
Now, calculate the median value of Screen once aga# i# n.
Has it chang# e# d?

Hint: refer to existing mode and median functions to complete the # tas# k# .# 

Yes
No

# %%
# Find the median value of Screen column in the dataset.

# %%
df2 = df['Screen'].median()
print(' The median of "Screen" column is :', df2)
# Out:
#  The median of "Screen" column is : 15.6

# %%
# Next, calculate the most frequent value of the same Screen column.

# %%
df3 = df['Screen'].mode()
print(' The mode of "Screen" column is :', df3)
# Out:
#  The mode of "Screen" column is : Series([], Name: Screen, dtype: object)

# %%
# Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.

# %%
df["Screen"] = df["Screen"].fillna(df['Screen'].mode())

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen          2160
# Touch              0
# Final_Price        0
# dtype: int64

# %%
  # I made one error, I will read again the source using the suuggestion in FAQ

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv"
df_new = pd.read_csv(url)

# %%
df_new['Screen'].isnull().sum()
# Out:
# 4

# %%
df3
# Out:
# Series([], Name: Screen, dtype: object)

# %%
df_new.Screen.mode()
# Out:
# 0    15.6
# Name: Screen, dtype: float64

# %%
df_new.Screen.nunique()
# Out:
# 29

# %%
df_new.Screen.mode()
# Out:
# 0    15.6
# Name: Screen, dtype: float64

# %%
df_new.groupby(['Screen']).count()
# Out:
#         Laptop  Status  Brand  Model   CPU   RAM  Storage  Storage type  GPU  \
# Screen
# 10.10        1       1      1      1     1     1        1             1    0
# 10.50        7       7      7      7     7     7        7             7    0
# 10.95        1       1      1      1     1     1        1             1    0
# 11.60       16      16     16     16    16    16       16            12    0
# 12.00        4       4      4      4     4     4        4             0    0
# 12.30       13      13     13     13    13    13       13            10    0
# 12.40        6       6      6      6     6     6        6             5    0
# 12.50        1       1      1      1     1     1        1             1    0
# 13.00       27      27     27     27    27    27       27            23    0
# 13.30      131     131    131    131   131   131      131           126    0
# 13.40       19      19     19     19    19    19       19            19    8
# ...

# %%
df_new[df_new['Screen']==' ']
# Out:
# Empty DataFrame
# Columns: [Laptop, Status, Brand, Model, CPU, RAM, Storage, Storage type, GPU, Screen, Touch, Final Price]
# Index: []

# %%
 # Using FAQ suggestion about MODE

# %%
mode = df_new['Screen'].mode()

# %%
single_valor_mode = mode[0]

# %%
single_valor_mode
# Out:
# 15.6

# %%
 # FILLNA

# %%
df_new["Screen"] = df_new["Screen"].fillna(single_valor_mode)

# %%
df_new['Screen'].isnull().sum()
# Out:
# 0

# %%
df_new["Screen"]
# Out:
# 0       15.6
# 1       15.6
# 2       15.6
# 3       15.6
# 4       15.6
#         ...
# 2155    17.3
# 2156    17.3
# 2157    17.3
# 2158    13.4
# 2159    13.4
# Name: Screen, Length: 2160, dtype: float64

# %%
df_new['Screen'].median()
# Out:
# 15.6

# %%
 # Q7. Sum of weights
 # 1. Select all the "Innjoo" laptops from the dataset. # 2. 
 # 2. 
Select only columns RAM, Storage, Screen # 3. . # 3. 
Get the underlying  N umPy array. Let's call it  # 4. X # 4. .
Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result X # 5. T # 5. X.
Compute the inverse 6. X # 6. TX.
Create an array y with values [1100, 1300, 800, 900, 1000, 1 # 7. 1 # 7. 00].
Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the res # 8. u # 8. lt w.
What's the sum of all the elements of the  # r # esult?
Note: You just implemented linear regression. We'll talk about it in the next  # lesso # n.

 # 0.43 # 
 # 4 # 5.29
0
45.58
91.30

# %%
 # 1. Select all the "Innjoo" laptops from the dataset.

# %%
df_Injoo = df_new[df_new['Brand']=='Innjoo']

# %%
df_Injoo
# Out:
#                                                  Laptop Status   Brand Model  \
# 1478  InnJoo Voom Excellence Intel Celeron N4020/8GB...    New  Innjoo  Voom
# 1479  InnJoo Voom Excellence Pro Intel Celeron N4020...    New  Innjoo  Voom
# 1480  Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/...    New  Innjoo  Voom
# 1481  Innjoo Voom Laptop Max Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1482  Innjoo Voom Laptop Pro Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1483  Innjoo Voom Pro Intel Celeron N3350/6GB/128GB ...    New  Innjoo  Voom
#
#                 CPU  RAM  Storage Storage type  GPU  Screen Touch  Final Price
# 1478  Intel Celeron    8      256          SSD  NaN    15.6    No       311.37
# 1479  Intel Celeron    8      512          SSD  NaN    15.6    No       392.55
# 1480  Intel Celeron    4       64         eMMC  NaN    14.1    No       251.40
# 1481  Intel Celeron    6       64         eMMC  NaN    14.1    No       383.61
# ...

# %%
# 2. Select only columns RAM, Storage, Screen.

# %%
df_q7 = df_Injoo.loc[ : ,[ 'RAM', 'Storage','Screen'] ]

# %%
df_q7
# Out:
#       RAM  Storage  Screen
# 1478    8      256    15.6
# 1479    8      512    15.6
# 1480    4       64    14.1
# 1481    6       64    14.1
# 1482    6      128    14.1
# 1483    6      128    14.1

# %%
# 3. Get the underlying NumPy array. Let's call it X.

# %%
X = df_q7.values

# %%
X
# Out:
# array([[  8. , 256. ,  15.6],
#        [  8. , 512. ,  15.6],
#        [  4. ,  64. ,  14.1],
#        [  6. ,  64. ,  14.1],
#        [  6. , 128. ,  14.1],
#        [  6. , 128. ,  14.1]])

# %%
# 4. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.

# %%
XT = X.transpose()

# %%
XT
# Out:
# array([[  8. ,   8. ,   4. ,   6. ,   6. ,   6. ],
#        [256. , 512. ,  64. ,  64. , 128. , 128. ],
#        [ 15.6,  15.6,  14.1,  14.1,  14.1,  14.1]])

# %%
XTX = XT.dot(X)

# %%
XTX
# Out:
# array([[2.52000e+02, 8.32000e+03, 5.59800e+02],
#        [8.32000e+03, 3.68640e+05, 1.73952e+04],
#        [5.59800e+02, 1.73952e+04, 1.28196e+03]])

# %%
# 5. Compute the inverse of XTX.

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ 2.78025381e-01, -1.51791334e-03, -1.00809855e-01],
#        [-1.51791334e-03,  1.58286725e-05,  4.48052175e-04],
#        [-1.00809855e-01,  4.48052175e-04,  3.87214888e-02]])

# %%
 # 6. Create an array y with values [1100, 1300, 800, 900, 1000, 1100].

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100])

# %%
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100])

# %%
 # 7. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.

# %%
  w = XTX_inv.dot(XT)

# %%
    w
# Out:
# array([[ 0.26298349, -0.12560233, -0.40646389,  0.14958687,  0.05244042,
#          0.05244042],
#        [-0.00110155,  0.00295059,  0.00125892, -0.00177691, -0.00076387,
#         -0.00076387],
#        [-0.08772226,  0.0269791 ,  0.17140891, -0.0302108 , -0.00153546,
#         -0.00153546]])

# %%
   w = w.dot(y)

# %%
w
# Out:
# array([45.58076606,  0.42783519, 45.29127938])

# %%
 # 8. What's the sum of all the elements of the result?

# %%
sum_w = w.sum()

# %%
sum_w
# Out:
# 91.29988062995815

# %%
 # END
